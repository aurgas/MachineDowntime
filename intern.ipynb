# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("manufacturing_defect_dataset.csv")
df.head()
# Out:
#    ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0               202    13175.403783        86.648534              1
# 1               535    19770.046093        86.310664              4
# 2               960    19060.820997        82.132472              0
# 3               370     5647.606037        87.335966              5
# 4               206     7472.222236        81.989893              3
#
#    DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# 0    3.121492     63.463494                 9            0.052343
# 1    0.819531     83.697818                20            4.908328
# 2    4.514504     90.350550                 1            2.464923
# 3    0.638524     67.628690                 8            4.692476
# 4    3.867784     82.728334                 9            2.746726
#
#    InventoryTurnover  StockoutRate  WorkerProductivity  SafetyIncidents  \
# 0           8.630515      0.081322           85.042379                0
# 1           9.296598      0.038486           99.657443                7
# 2           5.097486      0.002887           92.819264                2
# 3           3.577616      0.055331           96.887013                8
# 4           6.851709      0.068047           88.315554                7
#
#    EnergyConsumption  EnergyEfficiency  AdditiveProcessTime  \
# 0        2419.616785          0.468947             5.551639
# 1        3915.566713          0.119485             9.080754
# 2        3392.385362          0.496392             6.562827
# 3        4652.400275          0.183125             8.097496
# 4        1581.630332          0.263507             6.406154
#
#    AdditiveMaterialCost  DefectStatus
# 0            236.439301             1
# 1            353.957631             1
# 2            396.189402             1
# 3            164.135870             1
# 4            365.708964             1

# %%
droped = ['EnergyEfficiency']
df = df.drop(columns=droped)
df.head()
# Out:
#    ProductionVolume  SupplierQuality  DefectRate  QualityScore  \
# 0               202        86.648534    3.121492     63.463494
# 1               535        86.310664    0.819531     83.697818
# 2               960        82.132472    4.514504     90.350550
# 3               370        87.335966    0.638524     67.628690
# 4               206        81.989893    3.867784     82.728334
#
#    MaintenanceHours  DowntimePercentage  InventoryTurnover  StockoutRate  \
# 0                 9            0.052343           8.630515      0.081322
# 1                20            4.908328           9.296598      0.038486
# 2                 1            2.464923           5.097486      0.002887
# 3                 8            4.692476           3.577616      0.055331
# 4                 9            2.746726           6.851709      0.068047
#
#    SafetyIncidents  EnergyConsumption  DefectStatus
# 0                0        2419.616785             1
# 1                7        3915.566713             1
# 2                2        3392.385362             1
# 3                8        4652.400275             1
# 4                7        1581.630332             1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 

X = df.drop('DefectStatus', axis=1)
y = df['DefectStatus']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print("Preprocessed Features (X):\n", X_scaled)
print("\nTraining Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)
print("\nTarget (y):\n", y)
# Out:
# Preprocessed Features (X):
#  [[-1.32078467 -0.55307669  0.28426678 ...  1.05732894 -1.58559346
#   -0.49328525]
#  [-0.05154394 -0.6117525  -1.47302006 ... -0.43037743  0.83164521
#    0.80388297]
#  [ 1.56835791 -1.33735286  1.34767337 ... -1.66676716 -0.89495384
#    0.35022192]
#  ...
#  [ 1.09191619  1.14587926  1.64176939 ... -1.56824104  0.14100559
#   -0.85660435]
#  [-0.9396313   0.21820717  0.99892821 ... -0.28708765  0.4863254
#   -1.26053445]
#  [-0.73762001 -1.08319876 -0.03329491 ...  0.07294249 -0.20431422
#   -0.3277434 ]]
#
# Training Set Shape: (2592, 10)
# Testing Set Shape: (648, 10)
#
# Target (y):
#  0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3235    0
# 3236    0
# 3237    1
# 3238    0
# 3239    0
# Name: DefectStatus, Length: 3240, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred_test = lr.predict(X_test)
LogisticRegressionScore = lr.score(X_test,y_test)
LogisticRegressionScore
# Out:
# 0.8842592592592593

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay



cm = confusion_matrix(y_test, y_pred_test)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], index=['Predict Positive:1', 'Predict Negative:0'])
cm_matrix
# Out:
#                     Actual Positive:1  Actual Negative:0
# Predict Positive:1                 44                 58
# Predict Negative:0                 17                529

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
pred = dt.predict(X_test)
score = accuracy_score(y_test,pred)


cm = confusion_matrix(y_test, pred)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], index=['Predict Positive:1', 'Predict Negative:0'])
print(cm_matrix)
print(score)
# Out:
#                     Actual Positive:1  Actual Negative:0
# Predict Positive:1                 80                 22
# Predict Negative:0                 29                517
# 0.9212962962962963

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 4)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
score = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], index=['Predict Positive:1', 'Predict Negative:0'])
print(cm_matrix)
print(score)
# Out:
#                     Actual Positive:1  Actual Negative:0
# Predict Positive:1                 61                 41
# Predict Negative:0                 57                489
# 0.8487654320987654
